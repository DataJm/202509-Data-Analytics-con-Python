# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/josemanuelbarrera/Documents/202509-Data-Analytics-con-Python/Live Coding/Clase 03'

# %%
(
    pd
    .read_csv("../../data/02audi.csv")
    .groupby("model")
    ["price"]
    .agg(conteo=("count"), promedio=("mean"))
    .reset_index()
    # .to_excel("resultado.xlsx")
)
# Out:
#    model  conteo      promedio
# 0     A1    1347  14327.750557
# 1     A2       1   2490.000000
# 2     A3    1929  17408.522032
# 3     A4    1381  20255.450398
# 4     A5     882  23577.114512
# 5     A6     748  22695.385027
# 6     A7     122  28865.516393
# 7     A8     118  34981.847458
# 8     Q2     822  22516.975669
# 9     Q3    1417  22999.261821
# 10    Q5     877  30445.688712
# 11    Q7     397  44788.319899
# 12    Q8      69  60115.014493
# 13    R8      28  97652.214286
# 14   RS3      33  34050.515152
# 15   RS4      31  50151.612903
# 16   RS5      29  51265.206897
# 17   RS6      39  55963.871795
# 18   RS7       1  33490.000000
# 19    S3      18  20379.444444
# 20    S4      12  31248.083333
# 21    S5       3  15980.000000
# 22    S8       4  33807.750000
# 23   SQ5      16  31415.812500
# 24   SQ7       8  49269.000000
# 25    TT     336  21784.452381
